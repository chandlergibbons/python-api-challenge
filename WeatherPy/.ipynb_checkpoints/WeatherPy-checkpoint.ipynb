# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
pip install citipy
# Out:
# Requirement already satisfied: citipy in /opt/anaconda3/lib/python3.7/site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in /opt/anaconda3/lib/python3.7/site-packages (from citipy) (0.16)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from scipy.stats import linregress
import csv

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 611

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#starting point for api retreval url
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

#a place to put our data once 
city_data = []

#starting statment for api pull
print("Beginning Data Retrieval")
print("------------------------")

#setting print starting numbers
record_count = 1
set_count = 1

#handles print iteration statments and builds the weblink line for asking the api
for i, city in enumerate(cities):
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    city_url = url + "&q=" + city
    print("Proccessing Record %s of set %s | %s" %(record_count, set_count, city))
    record_count += 1

#try's to grab all the data from json api request
    try:
    
        city_weather = requests.get(city_url).json()
        
        city_lat = city_weather["coord"]["lat"]
        
        city_lng = city_weather["coord"]["lon"]
        
        city_max_temp = city_weather["main"]["temp_max"]
        
        city_humidity = city_weather["main"]["humidity"]
    
        city_clouds = city_weather["clouds"]["all"]
        
        city_wind = city_weather["wind"]["speed"]
             
        city_country = city_weather["sys"]["country"]
        
        city_date = city_weather["dt"]
#try's to push all the collected items into a list of dictionaries       
        city_data.append({"City": city, 
                         "Lat": city_lat,
                         "Lng": city_lng,
                         "Max Temp": city_max_temp,
                         "Humidity": city_humidity,
                         "Cloudiness": city_clouds,
                         "Wind speed": city_wind,
                         "Country": city_country,
                         "Date": city_date})
#handles output if there is a problem within the collection proccess        
    except:
        print("city not found.skipping")
        pass
#ending statment    
print("-----------------")
print("data retrival complete")
print("-----------------")
# Out:
# Beginning Data Retrieval
# ------------------------
# Proccessing Record 1 of set 1 | ushuaia
# Proccessing Record 2 of set 1 | hofn
# Proccessing Record 3 of set 1 | albany
# Proccessing Record 4 of set 1 | tazovskiy
# Proccessing Record 5 of set 1 | jamestown
# Proccessing Record 6 of set 1 | galgani
# city not found.skipping
# Proccessing Record 7 of set 1 | nouadhibou
# Proccessing Record 8 of set 1 | kazalinsk
# city not found.skipping
# Proccessing Record 9 of set 1 | bluff
# Proccessing Record 10 of set 1 | rikitea
# Proccessing Record 11 of set 1 | puerto ayora
# Proccessing Record 12 of set 1 | kahului
# Proccessing Record 13 of set 1 | shchelyayur
# city not found.skipping
# Proccessing Record 14 of set 1 | hermanus
# Proccessing Record 15 of set 1 | kodiak
# Proccessing Record 16 of set 1 | atuona
# Proccessing Record 17 of set 1 | kaitangata
# Proccessing Record 18 of set 1 | toliary
# city not found.skipping
# Proccessing Record 19 of set 1 | narsaq
# Proccessing Record 20 of set 1 | dikson
# Proccessing Record 21 of set 1 | pevek
# Proccessing Record 22 of set 1 | comillas
# Proccessing Record 23 of set 1 | arraial do cabo
# Proccessing Record 24 of set 1 | altamont
# Proccessing Record 25 of set 1 | forest grove
# Proccessing Record 26 of set 1 | kupang
# Proccessing Record 27 of set 1 | ponta do sol
# Proccessing Record 28 of set 1 | provideniya
# Proccessing Record 29 of set 1 | namibe
# Proccessing Record 30 of set 1 | hamilton
# Proccessing Record 31 of set 1 | inhambane
# Proccessing Record 32 of set 1 | oussouye
# Proccessing Record 33 of set 1 | mataura
# Proccessing Record 34 of set 1 | attawapiskat
# city not found.skipping
# Proccessing Record 35 of set 1 | bambous virieux
# Proccessing Record 36 of set 1 | port alfred
# Proccessing Record 37 of set 1 | carnarvon
# Proccessing Record 38 of set 1 | qaqortoq
# Proccessing Record 39 of set 1 | mingshui
# Proccessing Record 40 of set 1 | lewiston
# Proccessing Record 41 of set 1 | butaritari
# Proccessing Record 42 of set 1 | broome
# Proccessing Record 43 of set 1 | sarkand
# Proccessing Record 44 of set 1 | perth
# Proccessing Record 45 of set 1 | nizhneyansk
# city not found.skipping
# Proccessing Record 46 of set 1 | sorong
# Proccessing Record 47 of set 1 | sao joao da barra
# Proccessing Record 48 of set 1 | palana
# Proccessing Record 49 of set 1 | snyder
# Proccessing Record 50 of set 1 | roanoke rapids
# Proccessing Record 1 of set 2 | avarua
# Proccessing Record 2 of set 2 | gizo
# Proccessing Record 7 of set 10 | sao filipe
# Proccessing Record 8 of set 10 | oum hadjer
# Proccessing Record 9 of set 10 | cedeno
# Proccessing Record 10 of set 10 | bac lieu
# Proccessing Record 11 of set 10 | san juan del parana
# Proccessing Record 12 of set 10 | port macquarie
# Proccessing Record 13 of set 10 | faanui
# Proccessing Record 14 of set 10 | boden
# Proccessing Record 15 of set 10 | marsh harbour
# Proccessing Record 16 of set 10 | lisa
# Proccessing Record 17 of set 10 | araouane
# Proccessing Record 18 of set 10 | alta floresta
# Proccessing Record 19 of set 10 | nishihara
# Proccessing Record 20 of set 10 | moctezuma
# Proccessing Record 21 of set 10 | mogadishu
# Proccessing Record 22 of set 10 | raudeberg
# Proccessing Record 23 of set 10 | yanchukan
# city not found.skipping
# Proccessing Record 24 of set 10 | luanda
# Proccessing Record 25 of set 10 | zhenlai
# Proccessing Record 26 of set 10 | menongue
# Proccessing Record 27 of set 10 | marysville
# Proccessing Record 28 of set 10 | dalbandin
# Proccessing Record 29 of set 10 | foca
# Proccessing Record 30 of set 10 | otorohanga
# Proccessing Record 31 of set 10 | grand centre
# city not found.skipping
# Proccessing Record 32 of set 10 | troitskoye
# Proccessing Record 33 of set 10 | rawson
# Proccessing Record 34 of set 10 | muros
# Proccessing Record 35 of set 10 | rundu
# Proccessing Record 36 of set 10 | piacabucu
# Proccessing Record 37 of set 10 | batagay
# Proccessing Record 38 of set 10 | shingu
# Proccessing Record 39 of set 10 | falakata
# Proccessing Record 40 of set 10 | ballina
# Proccessing Record 41 of set 10 | cartagena
# Proccessing Record 42 of set 10 | tiznit
# Proccessing Record 43 of set 10 | kieta
# Proccessing Record 44 of set 10 | kungalv
# Proccessing Record 45 of set 10 | dumbrava rosie
# Proccessing Record 46 of set 10 | vaitupu
# city not found.skipping
# Proccessing Record 47 of set 10 | madang
# Proccessing Record 48 of set 10 | ojinaga
# Proccessing Record 49 of set 10 | sandwick
# Proccessing Record 50 of set 10 | touros
# Proccessing Record 1 of set 11 | nemuro
# Proccessing Record 2 of set 11 | port lincoln
# Proccessing Record 3 of set 11 | batagay-alyta
# Proccessing Record 4 of set 11 | tynda
# Proccessing Record 5 of set 11 | lokosovo
# Proccessing Record 6 of set 11 | birao
# Proccessing Record 7 of set 11 | plettenberg bay
# Proccessing Record 8 of set 11 | vogar
# Proccessing Record 9 of set 11 | bo
# city not found.skipping
# Proccessing Record 10 of set 11 | olinda
# Proccessing Record 11 of set 11 | dongsheng
# Proccessing Record 12 of set 11 | kwinana
# Proccessing Record 13 of set 11 | barras
# Proccessing Record 14 of set 11 | conakry
# Proccessing Record 15 of set 11 | svatove
# Proccessing Record 16 of set 11 | karauzyak
# city not found.skipping
# Proccessing Record 17 of set 11 | wagar
# Proccessing Record 18 of set 11 | los llanos de aridane
# Proccessing Record 19 of set 11 | columbus
# Proccessing Record 20 of set 11 | norman wells
# Proccessing Record 21 of set 11 | tucuma
# Proccessing Record 22 of set 11 | ardistan
# city not found.skipping
# Proccessing Record 23 of set 11 | russell
# Proccessing Record 24 of set 11 | wad madani
# Proccessing Record 25 of set 11 | rungata
# city not found.skipping
# Proccessing Record 26 of set 11 | plastun
# Proccessing Record 27 of set 11 | igarka
# Proccessing Record 28 of set 11 | palabuhanratu
# city not found.skipping
# Proccessing Record 29 of set 11 | walvis bay
# Proccessing Record 30 of set 11 | taltal
# Proccessing Record 31 of set 11 | mehran
# Proccessing Record 32 of set 11 | lalganj
# Proccessing Record 33 of set 11 | panzhihua
# Proccessing Record 34 of set 11 | salalah
# Proccessing Record 35 of set 11 | voh
# Proccessing Record 36 of set 11 | eydhafushi
# Proccessing Record 37 of set 11 | lazaro cardenas
# Proccessing Record 38 of set 11 | lorengau
# Proccessing Record 39 of set 11 | korla
# Proccessing Record 40 of set 11 | puerto baquerizo moreno
# Proccessing Record 41 of set 11 | galiwinku
# city not found.skipping
# Proccessing Record 42 of set 11 | sharjah
# Proccessing Record 43 of set 11 | obluche
# city not found.skipping
# Proccessing Record 44 of set 11 | bolungarvik
# city not found.skipping
# Proccessing Record 45 of set 11 | myskhako
# Proccessing Record 46 of set 11 | daura
# Proccessing Record 47 of set 11 | oktyabrskoye
# Proccessing Record 48 of set 11 | victoria
# Proccessing Record 49 of set 11 | nandi hills
# Proccessing Record 50 of set 11 | louisbourg
# city not found.skipping
# Proccessing Record 1 of set 12 | mwinilunga
# Proccessing Record 2 of set 12 | tessalit
# Proccessing Record 3 of set 12 | kolda
# Proccessing Record 4 of set 12 | mandalgovi
# Proccessing Record 5 of set 12 | opochka
# Proccessing Record 6 of set 12 | umm lajj
# Proccessing Record 7 of set 12 | smoky lake
# Proccessing Record 8 of set 12 | luwuk
# Proccessing Record 9 of set 12 | qazanbulaq
# Proccessing Record 10 of set 12 | coolum beach
# Proccessing Record 11 of set 12 | lebane
# Proccessing Record 12 of set 12 | kuzino
# Proccessing Record 13 of set 12 | nichinan
# Proccessing Record 14 of set 12 | kamo
# Proccessing Record 15 of set 12 | winnemucca
# Proccessing Record 16 of set 12 | pareora
# Proccessing Record 17 of set 12 | langenhagen
# Proccessing Record 18 of set 12 | poya
# Proccessing Record 19 of set 12 | grand gaube
# Proccessing Record 20 of set 12 | garden city
# Proccessing Record 21 of set 12 | skelleftea
# Proccessing Record 22 of set 12 | rio tuba
# Proccessing Record 23 of set 12 | vardo
# Proccessing Record 24 of set 12 | banes
# Proccessing Record 25 of set 12 | mentok
# city not found.skipping
# Proccessing Record 26 of set 12 | vao
# Proccessing Record 27 of set 12 | lodja
# Proccessing Record 28 of set 12 | donegal
# Proccessing Record 29 of set 12 | manali
# Proccessing Record 30 of set 12 | umm jarr
# city not found.skipping
# Proccessing Record 31 of set 12 | yuzhno-yeniseyskiy
# city not found.skipping
# Proccessing Record 32 of set 12 | aldan
# Proccessing Record 33 of set 12 | ngukurr
# city not found.skipping
# Proccessing Record 34 of set 12 | tezu
# Proccessing Record 35 of set 12 | bay roberts
# Proccessing Record 36 of set 12 | manta
# Proccessing Record 37 of set 12 | arona
# Proccessing Record 38 of set 12 | nexo
# Proccessing Record 39 of set 12 | lephepe
# city not found.skipping
# Proccessing Record 40 of set 12 | borisoglebskiy
# Proccessing Record 41 of set 12 | san patricio
# Proccessing Record 42 of set 12 | shimoda
# Proccessing Record 43 of set 12 | maceio
# Proccessing Record 44 of set 12 | kiruna
# Proccessing Record 45 of set 12 | ville-marie
# Proccessing Record 46 of set 12 | lagos de moreno
# Proccessing Record 47 of set 12 | bonthe
# Proccessing Record 48 of set 12 | brae
# Proccessing Record 49 of set 12 | shilka
# Proccessing Record 50 of set 12 | zhanatas
# city not found.skipping
# Proccessing Record 1 of set 13 | olsztyn
# Proccessing Record 2 of set 13 | shaunavon
# Proccessing Record 3 of set 13 | pundaguitan
# Proccessing Record 4 of set 13 | tupik
# Proccessing Record 5 of set 13 | mecca
# Proccessing Record 6 of set 13 | opuwo
# Proccessing Record 7 of set 13 | boa vista
# Proccessing Record 8 of set 13 | la ronge
# Proccessing Record 9 of set 13 | fraga
# Proccessing Record 10 of set 13 | severobaykalsk
# Proccessing Record 11 of set 13 | kitgum
# -----------------
# data retrival complete
# -----------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#writes a csv and saves it to the designated file location
keys = city_data[0].keys()

with open('/Users/Chibbbins/desktop/python-api-challenge/VacationPy/city_data.csv', 'w', newline='')  as output_file:
    dict_writer = csv.DictWriter(output_file, keys)
    dict_writer.writeheader()
    dict_writer.writerows(city_data)

# %%
#opens the csv and coverts it to a dataframe
file_to_load = "city_data.csv"

raw_city_data = pd.read_csv(file_to_load)

raw_city_data.head()
# Out:
#          City    Lat    Lng  Max Temp  Humidity  Cloudiness  Wind speed  \
# 0    ambilobe -13.20  49.05     75.31        90         100        2.19
# 1     hualmay -11.10 -77.61     69.98        86         100        9.04
# 2  nanortalik  60.14 -45.24     25.18        90          69        5.35
# 3      rawson -43.30 -65.10     68.20        45          15       20.40
# 4       ronne  55.10  14.71     41.00        86          96       20.80
#
#   Country        Date
# 0      MG  1609288596
# 1      PE  1609288596
# 2      GL  1609288596
# 3      AR  1609288596
# 4      DK  1609288596

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#iterates through humidity and skips the removal proccess if 100% humidity is found
if raw_city_data['Humidity'].max() > 100:
    #  Get the indices of cities that have humidity over 100%.
    ind_100_plus = raw_city_data[raw_city_data['Humidity'] > 100].index.tolist()
    # Make a new DataFrame equal to the city data to drop all humidity outliers by index.
    clean_city_data = raw_city_data.drop(raw_city_data.index[ind_100_plus])
else:
    clean_city_data = raw_city_data

clean_city_data
# Out:
#                 City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0           ambilobe -13.20   49.05     75.31        90         100
# 1            hualmay -11.10  -77.61     69.98        86         100
# 2         nanortalik  60.14  -45.24     25.18        90          69
# 3             rawson -43.30  -65.10     68.20        45          15
# 4              ronne  55.10   14.71     41.00        86          96
# ..               ...    ...     ...       ...       ...         ...
# 556        porbandar  21.64   69.61     60.24        40          13
# 557           tupiza -21.45  -65.72     61.97        53          94
# 558  haines junction  60.75 -137.51     19.67        94         100
# 559       talcahuano -36.72  -73.12     62.60        72           0
# 560         rossland  49.08 -117.80     19.99        96         100
#
#      Wind speed Country        Date
# 0          2.19      MG  1609288596
# 1          9.04      PE  1609288596
# 2          5.35      GL  1609288596
# 3         20.40      AR  1609288596
# 4         20.80      DK  1609288596
# ..          ...     ...         ...
# 556       15.88      IN  1609288653
# 557        6.33      BO  1609288653
# 558        0.69      CA  1609288653
# 559       12.75      CL  1609288653
# 560        7.00      CA  1609288653
#
# [561 rows x 9 columns]

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.scatter(clean_city_data["Lat"], clean_city_data["Max Temp"])
plt.xlabel("Latitude")
plt.ylabel("Temperature")
plt.title(f"Latitude vs. Temperature Plot ({pd.Timestamp('today').strftime('%m/%d/%y')})")
plt.axis([-90, 90, -50, 110])
plt.grid()
plt.savefig('lat_vs_temp.png')
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(clean_city_data["Lat"], clean_city_data["Humidity"])
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.title(f"Latitude vs. Humidity Plot ({pd.Timestamp('today').strftime('%m/%d/%y')})")
plt.axis([-90, 90, 0, 110])
plt.grid()
plt.savefig('lat_vs_hum.png')
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(clean_city_data["Lat"], clean_city_data["Cloudiness"])
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.title(f"Latitude vs. Cloudiness Plot ({pd.Timestamp('today').strftime('%m/%d/%y')})")
plt.axis([-90, 90, -10, 110])
plt.grid()
plt.savefig('lat_vs_cloud.png')
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(clean_city_data["Lat"], clean_city_data["Wind speed"])
plt.xlabel("Latitude")
plt.ylabel("Wind speed")
plt.title(f"Latitude vs. Wind speed Plot ({pd.Timestamp('today').strftime('%m/%d/%y')})")
plt.axis([-90, 90, -5, 50])
plt.grid()
plt.savefig('lat_vs_wind.png')
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
clean_city_data_NH = clean_city_data[clean_city_data["Lat"] >= 0]
clean_city_data_SH = clean_city_data[clean_city_data["Lat"] < 0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = clean_city_data_NH["Lat"]
y_values = clean_city_data_NH["Max Temp"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,10),fontsize=15,color="red")
plt.xlabel("Max Temp")
plt.ylabel("Latitude")
plt.title("Northern Hemisphere - Max Temp vs. Latitude Linear Regression")
plt.show()

# %% [markdown]
# This first graph models a downward trend wear as max tempature increases the latitude decrease in the northern hemisphere. The closer the latitude gets to zero the warmer it will be.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = clean_city_data_SH["Max Temp"]
y_values = clean_city_data_SH["Lat"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(70,-53),fontsize=15,color="red")
plt.xlabel("Max Temp")
plt.ylabel("Latitude")
plt.title("Southern Hemisphere - Max Temp vs. Latitude Linear Regression")
plt.show()

# %% [markdown]
# This graph models a upward trend wear as max tempature increases the latitude increases in the southern hemesphere. The closer the latitude gets to zero the warmer it will be.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = clean_city_data_NH["Humidity"]
y_values = clean_city_data_NH["Lat"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(20,75),fontsize=15,color="red")
plt.xlabel("Humidity (%)")
plt.ylabel("Latitude")
plt.title("Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression")
plt.show()

# %% [markdown]
# This graph models a slight upward trend wear as humidity increases the latitude increases in the northern hemesphere.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = clean_city_data_SH["Humidity"]
y_values = clean_city_data_SH["Lat"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(15,-15),fontsize=15,color="red")
plt.xlabel("Humidity (%)")
plt.ylabel("Latitude")
plt.title("Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression")
plt.show()

# %% [markdown]
# This graph models an upward trend wear as humidity increases the latitude increases in the southern hemesphere.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = clean_city_data_NH["Cloudiness"]
y_values = clean_city_data_NH["Lat"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5,75),fontsize=15,color="red")
plt.xlabel("Cloudiness (%)")
plt.ylabel("Latitude")
plt.title("Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")
plt.show()

# %% [markdown]
# This graph models a slight upward trend without the regrestion it wold be hard to tell exactly what relationship exists between latitude and cloudiness. Acoording to the regression, as cloudyness increases the latitude increases in the northern hemesphere.

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = clean_city_data_SH["Cloudiness"]
y_values = clean_city_data_SH["Lat"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(10,-55),fontsize=15,color="red")
plt.xlabel("Cloudiness (%)")
plt.ylabel("Latitude")
plt.title("Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")
plt.show()

# %% [markdown]
# This graph models a slight upward trend. Without the regrestion it wold be hard to tell exactly what relationship exists between latitude and cloudiness. Acoording to the regression, as cloudyness increases the latitude increases in the southern hemesphere.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = clean_city_data_NH["Wind speed"]
y_values = clean_city_data_NH["Lat"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(23,10),fontsize=15,color="red")
plt.xlabel("Wind speed (mph)")
plt.ylabel("Latitude")
plt.title("Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression")
plt.show()

# %% [markdown]
# This graph models a slight upward trend without the regrestion it wold be hard to tell exactly what relationship exists between latitude and wind speed. Acoording to the regression, as windspeed increases the latitude increases in the northern hemesphere.

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = clean_city_data_SH["Wind speed"]
y_values = clean_city_data_SH["Lat"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,-55),fontsize=15,color="red")
plt.xlabel("Wind speed (mph)")
plt.ylabel("Latitude")
plt.title("Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression")
plt.show()

# %% [markdown]
# This graph models a slight downward trend as windspeed increases the latitude decreases in the southern hemesphere.
